# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafael-R-Q/Projeto-de-Consultoria-para-Imigra-o-do-Brasil-para-o-Canad-/blob/main/Brasil_imigrantes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization: criando gráficos com bibliotecas Python
# ![Python_logo_and_wordmark.svg.png](data:image/png;base64,...)

# %% [markdown]
# # Aula 01 - Conhecendo a biblioteca Matplotlib

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/imigrantes_canada.csv')
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
df.set_index('País', inplace=True)

# %%
anos = list(map(str,range(1980,2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = df.loc['Brasil',anos]

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
brasil_dict = {'Ano': brasil.index.tolist(),'Imigrates': brasil.values.tolist()}

# %%
dados_brasil = pd.DataFrame(brasil_dict)

# %%
dados_brasil
# Out:
#      Ano  Imigrates
# 0   1980        211
# 1   1981        220
# 2   1982        192
# 3   1983        139
# 4   1984        145
# 5   1985        130
# 6   1986        205
# 7   1987        244
# 8   1988        394
# 9   1989        650
# 10  1990        650
# 11  1991        877
# 12  1992       1066
# 13  1993        866
# 14  1994        566
# 15  1995        572
# 16  1996        586
# 17  1997        591
# 18  1998        531
# 19  1999        626
# 20  2000        845
# 21  2001        847
# 22  2002        745
# 23  2003        839
# 24  2004        917
# 25  2005        969
# 26  2006       1181
# 27  2007       1746
# 28  2008       2138
# 29  2009       2509
# 30  2010       2598
# 31  2011       1508
# 32  2012       1642
# 33  2013       1714

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8,4))
plt.plot(dados_brasil['Ano'],dados_brasil['Imigrates'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.title('Imigração do Barsil para o Canadá')
plt.xlabel('Ano')
plt.ylabel('Número de imigrantes')
plt.grid()
plt.show()

# %% [markdown]
# #Aula 01 - Desafio: comparando tendências de imigração
#
# Elaborar um gráfico que descreva as têndencias de iigração do Brasil e da Argentina para o Canadá

# %%
argentina = df.loc['Argentina',anos]

# %%
argentina_dict = {'Ano': argentina.index.tolist(),'Imigrates': argentina.values.tolist()}

# %%
dados_argentina = pd.DataFrame(argentina_dict)

# %%
dados_argentina
# Out:
#      Ano  Imigrates
# 0   1980        368
# 1   1981        426
# 2   1982        626
# 3   1983        241
# 4   1984        237
# 5   1985        196
# 6   1986        213
# 7   1987        519
# 8   1988        374
# 9   1989        538
# 10  1990        678
# 11  1991        763
# 12  1992       1023
# 13  1993       1022
# 14  1994        366
# 15  1995        380
# 16  1996        396
# 17  1997        391
# 18  1998        349
# 19  1999        318
# 20  2000        427
# 21  2001        635
# 22  2002        865
# 23  2003       1745
# 24  2004       1591
# 25  2005       1153
# 26  2006        847
# 27  2007        620
# 28  2008        540
# 29  2009        467
# 30  2010        459
# 31  2011        278
# 32  2012        263
# 33  2013        282

# %%
plt.figure(figsize = (8,4))
plt.plot(dados_brasil['Ano'],dados_brasil['Imigrates'],label = 'Brasil')
plt.plot(dados_argentina['Ano'],dados_argentina['Imigrates'], label = 'Argentina')
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.title('Imigração do Barsil e da Argentina para o Canadá')
plt.xlabel('Ano')
plt.ylabel('Número de imigrantes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Aula 02 - Criando figuras com Matplotlib

# %%
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['Ano'],dados_brasil['Imigrates'])
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013')
ax.set_xlabel('Ano')
ax.set_ylabel('Número de imigrantes')
ax.grid()
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize = (15,5))

axs[0].plot(dados_brasil['Ano'],dados_brasil['Imigrates'])
axs[0].set_title('Imigração do Brasil para o Canadá\n1980 a 2013')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Número de imigrantes')
axs[0].grid()
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))

axs[1].boxplot(dados_brasil['Imigrates'])
axs[1].set_title('Boxplot da imigração do Brasil para o Canadá\n1980 a 2013')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de imigrantes')
axs[1].grid()

plt.show()

# %%
df
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
fig, axs = plt.subplots(2,2, figsize=(10,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Imigração dos quatro maiores países da América do Sul para o Canadá de 1980 a 2013')

axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

for ax in axs.flat:
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))

for ax in axs.flat:
  ax.set_xlabel('Ano')
  ax.set_ylabel('Número de Imigrantes')


ymin = 0
ymax = 7000

for ax in axs.ravel():
  ax.set_ylim(ymin,ymax)

plt.show()

# %% [markdown]
# # Aula 02 - Desafio: visualizando dados de vendas de diferentes lojas

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

# %%
dados = pd.DataFrame(vendas_2022, index = lojas)
dados
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
fig, axs = plt.subplots(2,2, figsize=(14,8))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Vendas no ano de 2022 nas quatro lojas')

axs[0,0].plot(dados.loc['A'])
axs[0,0].set_title('Vendas na Loja A')
#axs[0,0].grid()

axs[0,1].plot(dados.loc['B'])
axs[0,1].set_title('Vendas na Loja B')

axs[1,0].plot(dados.loc['C'])
axs[1,0].set_title('Vendas na Loja C')

axs[1,1].plot(dados.loc['D'])
axs[1,1].set_title('Vendas na Loja D')

#for ax in axs.flat:
#  ax.xaxis.set_major_locator(plt.MultipleLocator(3))

for ax in axs.flat:
  ax.set_xlabel('Meses')
  ax.set_ylabel('Total de vendas')


ymin = 0
ymax = 500

for ax in axs.ravel():
  ax.set_ylim(ymin,ymax)

for ax in axs.flat:
  ax.grid()

plt.show()

# %% [markdown]
# # Aula 03 - Customizando com Matplotlib

# %%
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['Ano'],dados_brasil['Imigrates'], lw = 3)
ax.set_title('Imigração do Brasil para o Canadá no periodo de 1980 a 2013', fontsize = 18, loc = 'left')
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de imigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.grid(linestyle = '--')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['Ano'],dados_brasil['Imigrates'], lw = 3, color = 'g')
ax.set_title('Imigração do Brasil para o Canadá no periodo de 1980 a 2013', fontsize = 18, loc = 'left')
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de imigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %% [markdown]
# Criando um gráfico de barras que apresente o número total de imigrantes dos países da América do Sul para o Canadá

# %%
america_sul = df.query('Região == "América do Sul"')
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize = (12,5))
ax.barh(america_sul.index, america_sul['Total'], color =cores)
ax.set_title('Imigração dos países da América do Sul para o Canadá\n no periodo de 1980 a 2013', fontsize = 18, loc = 'left')
ax.set_ylabel('', fontsize = 14)
ax.set_xlabel('Número de imigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %% [markdown]
# Colocando as informaçoes do gráfico de barras invertidas na ordem decrescente

# %%
america_sul_sorted = america_sul.sort_values('Total', ascending=True)

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize = (12,5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color =cores)
ax.set_title('Imigração dos países da América do Sul para o Canadá\n no periodo de 1980 a 2013', fontsize = 18, loc = 'left')
ax.set_ylabel('', fontsize = 14)
ax.set_xlabel('Número de imigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %% [markdown]
# Agora, faremos esse gráfico dando ênfase ao Brasil

# %%
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color =cores)
ax.set_title('América do Sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no periodp de 1980 a 2013 ', fontsize = 18, loc = 'left')
ax.set_ylabel('', fontsize = 14)
ax.set_xlabel('Número de imigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %% [markdown]
# Agora, serão adicionandos os valores de imigrantes a frente de cada barra, e serão retirados o eixo x, os marcadores do eixo y e a caixa preta.

# %%
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color =cores)
ax.set_title('América do Sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no periodp de 1980 a 2013 ', fontsize = 18, loc = 'left')
ax.set_ylabel('', fontsize = 14)
ax.set_xlabel('Número de imigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va='center')

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis='both', which='both', length=0)

plt.show()

# %% [markdown]
# Agora, os gráficos serão salvos em arquivos png

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
fig, ax = plt.subplots(figsize = (8,4))
ax.plot(dados_brasil['Ano'],dados_brasil['Imigrates'], lw = 3, color = 'g')
ax.set_title('Imigração do Brasil para o Canadá no periodo de 1980 a 2013', fontsize = 18, loc = 'left')
ax.set_xlabel('Ano', fontsize = 14)
ax.set_ylabel('Número de imigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig('imigracao_Brasil_canada.png',transparent = False, dpi = 300, bbox_inches='tight')

plt.show()

# %%
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize = (12,5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color =cores)
ax.set_title('América do Sul: Brasil foi o quarto país com mais imigrantes\n para o Canadá no periodo de 1980 a 2013 ', fontsize = 18, loc = 'left')
ax.set_ylabel('', fontsize = 14)
ax.set_xlabel('Número de imigrantes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va='center')

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis='both', which='both', length=0)

fig.savefig('imigracao_america_sul_canada.png',transparent = False, dpi = 300, bbox_inches='tight')

plt.show()

# %% [markdown]
# # Aula 03 - Desafio: customizando os subplots com dados de vendas de diferentes lojas

# %%
# Criar a figura e os subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 8))

# Ajustar os espaçamentos entre os subplots
plt.subplots_adjust(wspace=0.3, hspace=0.4)

# Adicionando um título geral para os subplots
fig.suptitle('Vendas no período de janeiro a dezembro de 2022 nas lojas A,B,C e D', fontsize=20)

# Lista de cores
cores = ['darkviolet', 'green', 'darkblue', 'coral']

#Loop para plotar e customizar os subplots
for i, ax in enumerate(axs.flat):
    ax.plot(dados.loc[dados.index[i]], color=cores[i], lw=3)
    ax.set_title(f'Vendas na loja {df.index[i]}', loc='left', fontsize=16)
    ax.set_xlabel('Mês', fontsize=14)
    ax.set_ylabel('Número de vendas', fontsize=14)
    ax.tick_params(labelsize=12)
    ax.grid(color='lightgrey')

# %% [markdown]
# # Aula 04 - Conhecendo a biblioteca Seaborn

# %%
import seaborn as sns

# %%
sns.set_theme()

# %% [markdown]
# Agora, vamos plotar um gráfico com os 10 países com maior número de imigrações para o Canadá

# %%
top_10 = df.sort_values('Total', ascending=False).head(10)
top_10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
sns.barplot(data=top_10, x = top_10.index, y = 'Total', hue=top_10.index, palette='Set2')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
sns.barplot(data=top_10, y = top_10.index, x = 'Total', hue=top_10.index, palette='Set2')
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
ax = sns.barplot(data=top_10, y = top_10.index, x = 'Total', hue=top_10.index, palette='Set2')
ax.set(title = 'Países com maior imigração para o Canadá\n 1980 a 2013',
       xlabel = 'Número de Imigrantes',
       ylabel = '')
plt.show()

# %%
fig,ax = plt.subplots(figsize=(8,4))

ax = sns.barplot(data=top_10, y = top_10.index, x = 'Total', hue=top_10.index, palette='Set2')
ax.set_title('Países com maior imigração para o Canadá\n 1980 a 2013', fontsize = 16, loc = 'left')
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')

plt.show()

# %% [markdown]
# Agora, será feita uma função que gera os gráficos de acordo com as paletas de cores apresentadas na biblioteca Seaborn. A documentação da biblioteca pode ser acessada no link https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
def gerar_grafico_paleta(palette):
  fig,ax = plt.subplots(figsize=(8,4))
  ax = sns.barplot(data=top_10, y = top_10.index, x = 'Total', hue=top_10.index, palette=palette)
  ax.set_title('Países com maior imigração para o Canadá\n 1980 a 2013', fontsize = 16, loc = 'left')
  ax.set_xlabel('Número de imigrantes', fontsize=14)
  ax.set_ylabel('')

plt.show()

# %%
gerar_grafico_paleta('Blues')

# %%
gerar_grafico_paleta('Greens_r')

# %%
gerar_grafico_paleta('rocket')

# %%
gerar_grafico_paleta('coolwarm_r')

# %%
gerar_grafico_paleta('tab10')

# %% [markdown]
# Testando os diferentes temas para gráficos apresentados na biblioteca Seaborn

# %%
sns.set_theme(style='dark')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='whitegrid')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='white')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='ticks')
gerar_grafico_paleta('tab10')

# %% [markdown]
# Retirando as linhas da borda superior e lateral direita do gráfico

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='tab10')

ax.set_title('Países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('')
sns.despine()

plt.show()
# Out:
# <ipython-input-55-59cc5351a230>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='tab10')

# %% [markdown]
# # Aula 04 - Desafio: criando um gráfico de linhas com a biblioteca Seaborn

# %%
sns.set_theme()
sns.set_palette('Dark2')

fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.lineplot(df.loc['Brasil', anos], label='Brasil', lw=3)
ax = sns.lineplot(df.loc['Argentina', anos], label='Argentina', lw=3)
ax = sns.lineplot(df.loc['Peru', anos], label='Peru', lw=3)
ax = sns.lineplot(df.loc['Colômbia', anos], label='Colômbia', lw=3)

ax.set_title('Imigração dos maiores países da América do Sul\npara o Canadá de 1980 a 2013', loc='left', fontsize=20)
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Número de imigrantes', fontsize=14)

ax.xaxis.set_major_locator(plt.MultipleLocator(5))

ax.legend(title='Países', loc='upper right', bbox_to_anchor=(1.18, 1.02))

plt.show()

# %% [markdown]
# #Aula 05 - Gráficos interativos com Plotly

# %%
import plotly.express as px

# %%
dados_brasil
# Out:
#      Ano  Imigrates
# 0   1980        211
# 1   1981        220
# 2   1982        192
# 3   1983        139
# 4   1984        145
# 5   1985        130
# 6   1986        205
# 7   1987        244
# 8   1988        394
# 9   1989        650
# 10  1990        650
# 11  1991        877
# 12  1992       1066
# 13  1993        866
# 14  1994        566
# 15  1995        572
# 16  1996        586
# 17  1997        591
# 18  1998        531
# 19  1999        626
# 20  2000        845
# 21  2001        847
# 22  2002        745
# 23  2003        839
# 24  2004        917
# 25  2005        969
# 26  2006       1181
# 27  2007       1746
# 28  2008       2138
# 29  2009       2509
# 30  2010       2598
# 31  2011       1508
# 32  2012       1642
# 33  2013       1714

# %%
fig = px.line(dados_brasil, x='Ano', y='Imigrates',
              title='Imigração do Brasil para o Canadá no período de 1980 a 2013')
fig.update_layout(
    width=1000, height=500,
    xaxis={'tickangle': -45},
    font_family='Arial',
    font_size=14,
    font_color='grey',
    title_font_color='black',
    title_font_size=22,
    xaxis_title='Ano',
    yaxis_title='Número de imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.update_traces(line_color='green', line_width=4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_america_sul_clean = america_sul.drop(['Continente', 'Região', 'Total'], axis=1)
america_sul_final = df_america_sul_clean.T

# %%
america_sul_final.head()
# Out:
# País  Argentina  Bolívia  Brasil  Chile  Colômbia  Equador  Guiana  Paraguai  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
#
# País  Peru  Suriname  Uruguai  Venezuela
# 1980   317        15      128        103
# 1981   456        10      132        117
# 1982   401        21      146        174
# 1983   241        12      105        124
# 1984   306         5       90        142

# %%
fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns, color='País', markers=True,
              title='Imigração dos países da América do Sul para o Canadá de 1980 a 2013')
fig.update_layout(
    xaxis={'tickangle': -45},
    xaxis_title='Ano',
    yaxis_title='Número de imigrantes')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html('imigracao_america_sul.html')

# %%
argentina = df.loc['Argentina',anos]
argentina_dict = {'Ano': argentina.index.tolist(),'Imigrantes': argentina.values.tolist()}
dados_argentina = pd.DataFrame(argentina_dict)
dados_argentina
# Out:
#      Ano  Imigrantes
# 0   1980         368
# 1   1981         426
# 2   1982         626
# 3   1983         241
# 4   1984         237
# 5   1985         196
# 6   1986         213
# 7   1987         519
# 8   1988         374
# 9   1989         538
# 10  1990         678
# 11  1991         763
# 12  1992        1023
# 13  1993        1022
# 14  1994         366
# 15  1995         380
# 16  1996         396
# 17  1997         391
# 18  1998         349
# 19  1999         318
# 20  2000         427
# 21  2001         635
# 22  2002         865
# 23  2003        1745
# 24  2004        1591
# 25  2005        1153
# 26  2006         847
# 27  2007         620
# 28  2008         540
# 29  2009         467
# 30  2010         459
# 31  2011         278
# 32  2012         263
# 33  2013         282

# %%
dados_brasil['Ano'] = dados_brasil['Ano'].astype(int)

# %%
dados_argentina['Ano'] = dados_argentina['Ano'].astype(int)

# %%
import plotly.graph_objs as go

# # Criando uma figura
fig = go.Figure()

# Adicionando a linha com os dados do Brasil
fig.add_trace(
    go.Scatter(x=[dados_brasil['Ano'].iloc[0]], y=[dados_brasil['Imigrates'].iloc[0]], mode='lines', name='Imigrantes do Brasil', line=dict(width=4))
)

# Adicionando a linha com os dados da Argentina
fig.add_trace(
    go.Scatter(x=[dados_argentina['Ano'].iloc[0]], y=[dados_argentina['Imigrantes'].iloc[0]], mode='lines', name='Imigrantes da Argentina', line=dict(width=4))
)

# Definindo as configurações de layout
fig.update_layout(
    title=dict(
        text='<b>Imigração do Brasil e da Argentina para o Canadá no período de 1980 a 2013',
        x=0.1,

        font=dict(size=18)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Ano</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de imigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1200, # largura da figura em pixels
    height=600 # altura da figura em pixels
)

# Definindo as configurações de animação
frames = []
for i in range(len(dados_brasil)):
    frame_data = [
        go.Scatter(x=dados_brasil['Ano'].iloc[:i+1], y=dados_brasil['Imigrates'].iloc[:i+1]),
        go.Scatter(x=dados_argentina['Ano'].iloc[:i+1], y=dados_argentina['Imigrantes'].iloc[:i+1])
    ]
    frame = go.Frame(data=frame_data)
    frames.append(frame)
fig.frames = frames

# Mostrando a figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
